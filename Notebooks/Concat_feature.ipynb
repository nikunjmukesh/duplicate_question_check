# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_1 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features300000', compression='gzip')
df_2 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features600000', compression='gzip')
df_3 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features900000', compression='gzip')
df_4 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features1200000', compression='gzip')
df_5 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features1500000', compression='gzip')
df_6 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features1800000', compression='gzip')
df_7 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features2100000', compression='gzip')
df_8 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features2400000', compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-2678cef8b339> in <module>()
# ----> 1 df_1 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features300000', compression='gzip', index=False)
#       2 df_2 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features600000', compression='gzip')
#       3 df_3 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features900000', compression='gzip')
#       4 df_4 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features1200000', compression='gzip')
#       5 df_5 = pd.read_pickle('../Features/Test/test pappu semantic/Semantic_features1500000', compression='gzip')
#
# TypeError: read_pickle() got an unexpected keyword argument 'index'

# %%
df_2
# Out:
#         euclidean    cosine  cosine_angle    canberra  correlation
# 0        0.443819  0.098488     84.347916  121.703426     0.098721
# 1        0.756463  0.286118     73.374322  174.745973     0.285929
# 2        1.274879  0.812659     35.643473  217.444072     0.812577
# 3        0.832036  0.346142     69.748458  172.855011     0.344727
# 4        0.534008  0.142582     81.802707  143.290187     0.142566
# 5        0.280966  0.039471     87.737890  114.101327     0.038922
# 6        0.552668  0.152721     81.215349  155.336332     0.152057
# 7        0.916159  0.419674     65.186013  201.754888     0.420845
# 8        0.655534  0.214862     77.592541  174.660079     0.214413
# 9        0.234924  0.027595     88.418742   89.595683     0.027579
# 10       0.550565  0.151561     81.282598  148.401014     0.151191
# 11       0.865453  0.374504     68.006333  176.324576     0.376711
# 12       0.475207  0.112911     83.516868  141.753359     0.112862
# ...

# %%
df_feat = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8], ignore_index=True)

# %%
df_feat
# Out:
#          euclidean    cosine  cosine_angle    canberra  correlation
# 0         0.692907  0.240060     76.109897  171.820267     0.239916
# 1         0.442576  0.097937     84.379630  135.593661     0.097695
# 2         0.315712  0.049837     87.143368  110.121861     0.050068
# 3         0.980695  0.480882     61.256992  191.740844     0.480435
# 4         1.027722  0.528106     58.122437  183.052060     0.527327
# 5         1.043360  0.544300     57.023188  187.793410     0.544491
# 6         0.422325  0.089179     84.883605  123.328547     0.088744
# 7         0.696893  0.242830     75.946369  179.046443     0.243484
# 8         0.503261  0.126636     82.724755  158.994797     0.123950
# 9         0.446061  0.099485     84.290482  131.736621     0.099112
# 10        0.548059  0.150184     81.362389  129.669943     0.150152
# 11        0.527835  0.139305     81.992388  139.485760     0.139174
# 12        0.921007  0.424127     64.904610  191.537852     0.423645
# ...

# %%
train = pd.read_csv('../Data/train_cleaned.csv')

# %%
df_feat['is_duplicate'] = train['is_duplicate']

# %%
df_feat.to_pickle('../Features/Test/Semantic_features', compression='gzip')

# %%
df_feat.to_csv('../Features/Test/Semantic_features.csv', index=False)

# %%
cor = df_feat.corr()
fig, ax = plt.subplots(figsize=(25, 25))
sns.heatmap(cor, annot=True)
